# %% [markdown]
# # Face Generation
#
# In this project, you'll define and train a DCGAN on a dataset of faces. Your goal is to get a generator network to generate *new* images of faces that look as realistic as possible!
#
# The project will be broken down into a series of tasks from **loading in data to defining and training adversarial networks**. At the end of the notebook, you'll be able to visualize the results of your trained Generator to see how it performs; your generated samples should look like fairly realistic faces with small amounts of noise.
#
# ### Get the Data
#
# You'll be using the [CelebFaces Attributes Dataset (CelebA)](http://mmlab.ie.cuhk.edu.hk/projects/CelebA.html) to train your adversarial networks.
#
# This dataset is more complex than the number datasets (like MNIST or SVHN) you've been working with, and so, you should prepare to define deeper networks and train them for a longer time to get good results. It is suggested that you utilize a GPU for training.
#
# ### Pre-processed Data
#
# Since the project's main focus is on building the GANs, we've done *some* of the pre-processing for you. Each of the CelebA images has been cropped to remove parts of the image that don't include a face, then resized down to 64x64x3 NumPy images. Some sample data is show below.
#
# <img src='assets/processed_face_data.png' width=60% />
#
# > If you are working locally, you can download this data [by clicking here](https://s3.amazonaws.com/video.udacity-data.com/topher/2018/November/5be7eb6f_processed-celeba-small/processed-celeba-small.zip)
#
# This is a zip file that you'll need to extract in the home directory of this notebook for further loading and processing. After extracting the data, you should be left with a directory of data `processed_celeba_small/`

# %%
# can comment out after executing
# !unzip processed_celeba_small.zip

# %%
data_dir = 'processed_celeba_small/'

"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import pickle as pkl
import matplotlib.pyplot as plt
import numpy as np
import problem_unittests as tests
#import helper

# %matplotlib inline

# %% [markdown]
# ## Visualize the CelebA Data
#
# The [CelebA](http://mmlab.ie.cuhk.edu.hk/projects/CelebA.html) dataset contains over 200,000 celebrity images with annotations. Since you're going to be generating faces, you won't need the annotations, you'll only need the images. Note that these are color images with [3 color channels (RGB)](https://en.wikipedia.org/wiki/Channel_(digital_image)#RGB_Images) each.
#
# ### Pre-process and Load the Data
#
# Since the project's main focus is on building the GANs, we've done *some* of the pre-processing for you. Each of the CelebA images has been cropped to remove parts of the image that don't include a face, then resized down to 64x64x3 NumPy images. This *pre-processed* dataset is a smaller subset of the very large CelebA data.
#
# > There are a few other steps that you'll need to **transform** this data and create a **DataLoader**.
#
# #### Exercise: Complete the following `get_dataloader` function, such that it satisfies these requirements:
#
# * Your images should be square, Tensor images of size `image_size x image_size` in the x and y dimension.
# * Your function should return a DataLoader that shuffles and batches these Tensor images.
#
# #### ImageFolder
#
# To create a dataset given a directory of images, it's recommended that you use PyTorch's [ImageFolder](https://pytorch.org/docs/stable/torchvision/datasets.html#imagefolder) wrapper, with a root directory `processed_celeba_small/` and data transformation passed in.

# %%
# necessary imports
import torch
import torchvision
from torchvision import datasets
from torchvision import transforms

# %%
def get_dataloader(batch_size, image_size, data_dir='processed_celeba_small/'):
    """
    Batch the neural network data using DataLoader
    :param batch_size: The size of each batch; the number of images in a batch
    :param img_size: The square size of the image data (x, y)
    :param data_dir: Directory where image data is located
    :return: DataLoader with batched data
    """
    
    # TODO: Implement function and return a dataloader
    transform = transforms.Compose([transforms.Resize((image_size, image_size)),
                                    transforms.ToTensor()])  # use a tuple in resize to ensure square imgs
    dataset = torchvision.datasets.ImageFolder(data_dir, transform=transform)
    dataloader = torch.utils.data.DataLoader(dataset, batch_size, shuffle=True, num_workers=0)
    
    return dataloader

# %% [markdown]
# ## Create a DataLoader
#
# #### Exercise: Create a DataLoader `celeba_train_loader` with appropriate hyperparameters.
#
# Call the above function and create a dataloader to view images.
# * You can decide on any reasonable `batch_size` parameter
# * Your `image_size` **must be** `32`. Resizing the data to a smaller size will make for faster training, while still creating convincing images of faces!

# %%
# Define function hyperparameters
batch_size = 128
img_size = 32

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
# Call your function and get a dataloader
celeba_train_loader = get_dataloader(batch_size, img_size)

# %% [markdown]
# Next, you can view some images! You should seen square images of somewhat-centered faces.
#
# Note: You'll need to convert the Tensor images into a NumPy type and transpose the dimensions to correctly display an image, suggested `imshow` code is below, but it may not be perfect.

# %%
# helper display function
def imshow(img):
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)))

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
# obtain one batch of training images
dataiter = iter(celeba_train_loader)
images, _ = dataiter.next() # _ for no labels

# plot the images in the batch, along with the corresponding labels
fig = plt.figure(figsize=(20, 4))
plot_size=20
for idx in np.arange(plot_size):
    ax = fig.add_subplot(2, plot_size/2, idx+1, xticks=[], yticks=[])
    imshow(images[idx])

# %% [markdown]
# #### Exercise: Pre-process your image data and scale it to a pixel range of -1 to 1
#
# You need to do a bit of pre-processing; you know that the output of a `tanh` activated generator will contain pixel values in a range from -1 to 1, and so, we need to rescale our training images to a range of -1 to 1. (Right now, they are in a range from 0-1.)

# %%
# TODO: Complete the scale function
def scale(x, feature_range=(-1, 1)):
    ''' Scale takes in an image x and returns that image, scaled
       with a feature_range of pixel values from -1 to 1. 
       This function assumes that the input x is already scaled from 0-1.'''
    # assume x is scaled to (0, 1)
    # scale to feature_range and return scaled x
    low_range, high_range = feature_range
    x = x * (high_range-low_range) - high_range   # to be within [-1;+1] coherent with Tanh activation
    return x

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
# check scaled range
# should be close to -1 to 1
img = images[0]
scaled_img = scale(img)

print('Min: ', scaled_img.min())
print('Max: ', scaled_img.max())
# Out:
# Min:  tensor(-0.9686)
# Max:  tensor(0.8667)

# %% [markdown]
# ---
# # Define the Model
#
# A GAN is comprised of two adversarial networks, a discriminator and a generator.
#
# ## Discriminator
#
# Your first task will be to define the discriminator. This is a convolutional classifier like you've built before, only without any maxpooling layers. To deal with this complex data, it's suggested you use a deep network with **normalization**. You are also allowed to create any helper functions that may be useful.
#
# #### Exercise: Complete the Discriminator class
# * The inputs to the discriminator are 32x32x3 tensor images
# * The output should be a single value that will indicate whether a given image is real or fake

# %%
import torch.nn as nn
import torch.nn.functional as F

# %%
# helper function down-sampling XY dimensions by 2. batchNorm and LeakyRelu used upon request

def convlayer(dim_in, dim_out, kernel_size, batch_norm, relu, stride=2, padding=1):
    layers = []
    layers.append(nn.Conv2d(dim_in, dim_out, kernel_size, stride, padding, bias=False))
    if batch_norm :
        layers.append(nn.BatchNorm2d(dim_out))
    if relu:
        layers.append(nn.LeakyReLU(0.2))
    return nn.Sequential(*layers)

# %%
class Discriminator(nn.Module):

    def __init__(self, conv_dim):
        """
        Initialize the Discriminator Module
        :param conv_dim: The depth of the first convolutional layer
        """
        super(Discriminator, self).__init__()

        # complete init function
        self.conv_dim = conv_dim
        
        # input: 3x32x32  out:32x16x16
        self.conv1 = convlayer(3, conv_dim, 4, batch_norm = False, relu = True)
        # input: 32x16x16  out:64x8x8
        self.conv2 = convlayer(conv_dim, conv_dim * 2, 4, batch_norm = True, relu = True)
        # input: 64x8x8  out:128x4x4
        self.conv3 = convlayer(conv_dim * 2, conv_dim * 4, 4, batch_norm = True, relu = True)
        # input: 128x4x4  out:256x2x2
        self.conv4 = convlayer(conv_dim * 4, conv_dim * 8, 4, batch_norm = True, relu = True)
        # input: 256x2x2  out:1x1x1
        self.conv5 = convlayer(conv_dim * 8, 1, 4, batch_norm = False, relu = False)
        
        # tried to used a FC layer as classifier but model could not properly converge
        # => discarded aligned with recommendation on stable architectures for DC GANs
        #self.FC1 = nn.Linear(conv_dim * 8 * 2 * 2, conv_dim * 8 * 2)
        #self.FC2 = nn.Linear(conv_dim * 8 * 2, conv_dim * 8)
        #self.FC3 = nn.Linear(conv_dim * 8, 1)
        

    def forward(self, x):
        """
        Forward propagation of the neural network
        :param x: The input to the neural network     
        :return: Discriminator logits; the output of the neural network
        """
        # define feedforward behavior
        self.batch_size = x.shape[0]
        
        x = self.conv1(x)
        x = self.conv2(x)
        x = self.conv3(x)
        x = self.conv4(x)
        
        x = self.conv5(x)   # tensor shape of batch_sizex1x1x1
        x = x.view(-1,1)    # resizing tensor for single output value
                            # No activation function like in CycleGAN project - Not clear WHY????
        
        # tried to used a FC layer as classifier but model could not properly converge => discarded
        #x = x.view(-1, self.conv_dim * 8 * 2 * 2)  # alternative flattening
        #x = x.view(self.batch_size, -1)            # flattening for FC layer
        #x = F.relu(self.FC1(x))
        #x = F.relu(self.FC2(x))
        #x = self.FC3(x)
        #x = F.sigmoid(x)   # usage depends on the loss function and if loss function includes activation
                
        return x


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_discriminator(Discriminator)
# Out:
# Tests Passed

# %%
print(Discriminator(32))
# Out:
# Discriminator(
#   (conv1): Sequential(
#     (0): Conv2d(3, 32, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): LeakyReLU(negative_slope=0.2)
#   )
#   (conv2): Sequential(
#     (0): Conv2d(32, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): LeakyReLU(negative_slope=0.2)
#   )
#   (conv3): Sequential(
#     (0): Conv2d(64, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): LeakyReLU(negative_slope=0.2)
#   )
#   (conv4): Sequential(
#     (0): Conv2d(128, 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): LeakyReLU(negative_slope=0.2)
#   )
#   (conv5): Sequential(
#     (0): Conv2d(256, 1, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   )
# )

# %% [markdown]
# ## Generator
#
# The generator should upsample an input and generate a *new* image of the same size as our training data `32x32x3`. This should be mostly transpose convolutional layers with normalization applied to the outputs.
#
# #### Exercise: Complete the Generator class
# * The inputs to the generator are vectors of some length `z_size`
# * The output should be a image of shape `32x32x3`

# %%
# helper function up-sampling XY dimensions by 2. batchNorm and Relu used upon request

def transposeConvlayer(dim_in, dim_out, kernel_size, batch_norm, relu):
    layers=[]
    deconv= nn.ConvTranspose2d(dim_in, dim_out, kernel_size, stride=2, padding = 1, bias = False)
    layers.append(deconv)
    if batch_norm:
        layers.append(nn.BatchNorm2d(dim_out))
    if relu:
        layers.append(nn.ReLU())
    return nn.Sequential(*layers)

# %%
class Generator(nn.Module):
    
    def __init__(self, z_size, conv_dim):
        """
        Initialize the Generator Module
        :param z_size: The length of the input latent vector, z
        :param conv_dim: The depth of the inputs to the *last* transpose convolutional layer
        """
        super(Generator, self).__init__()

        # complete init function
        self.z_size = z_size
        self.conv_dim = conv_dim
        self.fc = nn.Linear(z_size, conv_dim * 8 * 2 * 2 )    # Fully Connected layer with vector z input and feature output
        # input: 256 x 2 x 2  out:128x4x4
        self.deconv1 = transposeConvlayer(dim_in=conv_dim*8, dim_out=conv_dim*4, kernel_size=4, batch_norm=True, relu=True)
        # input: 128x4x4  out:64x8x8
        self.deconv2 = transposeConvlayer(dim_in=conv_dim*4, dim_out=conv_dim*2, kernel_size=4, batch_norm=True, relu=True)
        # input: 64x8x8  out:32x16x16
        self.deconv3 = transposeConvlayer(dim_in=conv_dim*2, dim_out=conv_dim, kernel_size=4, batch_norm=True, relu=True)
        # input: 32x16x16  out:3x32x32
        self.deconv4 = transposeConvlayer(dim_in=conv_dim, dim_out=3, kernel_size=4, batch_norm=False, relu=False)

    def forward(self, x):
        """
        Forward propagation of the neural network
        :param x: The input to the neural network     
        :return: A 32x32x3 Tensor image as output
        """
        # define feedforward behavior
        
        self.batch_size = x.shape[0]
                
        x = self.fc(x)
        x = x.view(self.batch_size, -1, 2, 2)  # resizing feature vector into feature volume 256 x 2 x 2
        
        x = self.deconv1(x)
        x = self.deconv2(x)
        x = self.deconv3(x)
        x = F.tanh(self.deconv4(x))   # outputs will be within [-1;+1] range
        
        return x

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_generator(Generator)
# Out:
# Tests Passed

# %%
print(Generator(100, 32))
# Out:
# Generator(
#   (fc): Linear(in_features=100, out_features=1024, bias=True)
#   (deconv1): Sequential(
#     (0): ConvTranspose2d(256, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#   )
#   (deconv2): Sequential(
#     (0): ConvTranspose2d(128, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#   )
#   (deconv3): Sequential(
#     (0): ConvTranspose2d(64, 32, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#   )
#   (deconv4): Sequential(
#     (0): ConvTranspose2d(32, 3, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   )
# )

# %% [markdown]
# ## Initialize the weights of your networks
#
# To help your models converge, you should initialize the weights of the convolutional and linear layers in your model. From reading the [original DCGAN paper](https://arxiv.org/pdf/1511.06434.pdf), they say:
# > All weights were initialized from a zero-centered Normal distribution with standard deviation 0.02.
#
# So, your next task will be to define a weight initialization function that does just this!
#
# You can refer back to the lesson on weight initialization or even consult existing model code, such as that from [the `networks.py` file in CycleGAN Github repository](https://github.com/junyanz/pytorch-CycleGAN-and-pix2pix/blob/master/models/networks.py) to help you complete this function.
#
# #### Exercise: Complete the weight initialization function
#
# * This should initialize only **convolutional** and **linear** layers
# * Initialize the weights to a normal distribution, centered around 0, with a standard deviation of 0.02.
# * The bias terms, if they exist, may be left alone or set to 0.

# %%
def weights_init_normal(m):
    """
    Applies initial weights to certain layers in a model .
    The weights are taken from a normal distribution 
    with mean = 0, std dev = 0.02.
    :param m: A module or layer in a network    
    """
    # classname will be something like:
    # `Conv`, `BatchNorm2d`, `Linear`, etc.
    classname = m.__class__.__name__
    
    # TODO: Apply initial weights to convolutional and linear layers
    if classname.find('Conv') !=-1:
        m.weight.data.normal_(0, 0.02)
    #elif classname.find('BatchNorm2d') !=-1:
    #    m.weight.data.normal_(0, 0.02)
    elif classname.find('Linear') !=-1:
        m.weight.data.normal_(0, 0.02)

# %% [markdown]
# ## Build complete network
#
# Define your models' hyperparameters and instantiate the discriminator and generator from the classes defined above. Make sure you've passed in the correct input arguments.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
def build_network(d_conv_dim, g_conv_dim, z_size):
    # define discriminator and generator
    D = Discriminator(d_conv_dim)
    G = Generator(z_size=z_size, conv_dim=g_conv_dim)

    # initialize model weights
    D.apply(weights_init_normal)
    G.apply(weights_init_normal)

    print(D)
    print()
    print(G)
    
    return D, G

# %% [markdown]
# #### Exercise: Define model hyperparameters

# %%
# Define model hyperparams
d_conv_dim = 32
g_conv_dim = 32
z_size = 100

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
D, G = build_network(d_conv_dim, g_conv_dim, z_size)
# Out:
# Discriminator(
#   (conv1): Sequential(
#     (0): Conv2d(3, 32, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): LeakyReLU(negative_slope=0.2)
#   )
#   (conv2): Sequential(
#     (0): Conv2d(32, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): LeakyReLU(negative_slope=0.2)
#   )
#   (conv3): Sequential(
#     (0): Conv2d(64, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): LeakyReLU(negative_slope=0.2)
#   )
#   (conv4): Sequential(
#     (0): Conv2d(128, 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): LeakyReLU(negative_slope=0.2)
#   )
#   (conv5): Sequential(
#     (0): Conv2d(256, 1, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   )
# )
#
# Generator(
#   (fc): Linear(in_features=100, out_features=1024, bias=True)
#   (deconv1): Sequential(
#     (0): ConvTranspose2d(256, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#   )
#   (deconv2): Sequential(
#     (0): ConvTranspose2d(128, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#   )
#   (deconv3): Sequential(
#     (0): ConvTranspose2d(64, 32, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#   )
#   (deconv4): Sequential(
#     (0): ConvTranspose2d(32, 3, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   )
# )

# %% [markdown]
# ### Training on GPU
#
# Check if you can train on GPU. Here, we'll set this as a boolean variable `train_on_gpu`. Later, you'll be responsible for making sure that
# >* Models,
# * Model inputs, and
# * Loss function arguments
#
# Are moved to GPU, where appropriate.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import torch

# Check for a GPU
train_on_gpu = torch.cuda.is_available()
if not train_on_gpu:
    print('No GPU found. Please use a GPU to train your neural network.')
else:
    print('Training on GPU!')
# Out:
# Training on GPU!

# %% [markdown]
# ---
# ## Discriminator and Generator Losses
#
# Now we need to calculate the losses for both types of adversarial networks.
#
# ### Discriminator Losses
#
# > * For the discriminator, the total loss is the sum of the losses for real and fake images, `d_loss = d_real_loss + d_fake_loss`.
# * Remember that we want the discriminator to output 1 for real images and 0 for fake images, so we need to set up the losses to reflect that.
#
#
# ### Generator Loss
#
# The generator loss will look similar only with flipped labels. The generator's goal is to get the discriminator to *think* its generated images are *real*.
#
# #### Exercise: Complete real and fake loss functions
#
# **You may choose to use either cross entropy or a least squares error loss to complete the following `real_loss` and `fake_loss` functions.**

# %%
def real_loss(D_out):
    '''Calculates how close discriminator outputs are to being real.
       param, D_out: discriminator logits
       return: real loss'''
    loss = torch.mean((D_out - 1)**2)   # using Least square GAN loss function similar to CycleGAN
    return loss

def fake_loss(D_out):
    '''Calculates how close discriminator outputs are to being fake.
       param, D_out: discriminator logits
       return: fake loss'''
    loss = torch.mean((D_out - 0)**2)   # using Least square GAN loss function similar to CycleGAN
    return loss

# %%
criterion = nn.CrossEntropyLoss()

def CEL_real_loss(D_out):
    '''Calculates how close discriminator outputs are to being real.
       param, D_out: discriminator logits
       return: real loss'''
    batch_size = D_out.shape[0]
    target = torch.ones(batch_size)
    if train_on_gpu:
        target=target.cuda()
    loss = criterion(D_out.squeeze(), target)
    return loss

def CEL_fake_loss(D_out):
    '''Calculates how close discriminator outputs are to being fake.
       param, D_out: discriminator logits
       return: fake loss'''
    batch_size = D_out.shape[0]
    target = torch.zeros(batch_size)
    if train_on_gpu:
        target=target.cuda()
    loss = criterion(D_out.squeeze(), target)
    return loss

# %% [markdown]
# ## Optimizers
#
# #### Exercise: Define optimizers for your Discriminator (D) and Generator (G)
#
# Define optimizers for your models with appropriate hyperparameters.

# %%
import torch.optim as optim

lr = 0.0002     # hyperparameter recommended in litterature (original CycleGAN paper Jun-Yan Zhu)
beta1 = 0.5     # hyperparameter recommended in litterature
beta2 = 0.999   # hyperparameter recommended in litterature

# Create optimizers for the discriminator D and generator G
d_optimizer = optim.Adam(D.parameters(), lr, [beta1, beta2])
g_optimizer = optim.Adam(G.parameters(), lr, [beta1, beta2])

# %% [markdown]
# ---
# ## Training
#
# Training will involve alternating between training the discriminator and the generator. You'll use your functions `real_loss` and `fake_loss` to help you calculate the discriminator losses.
#
# * You should train the discriminator by alternating on real and fake images
# * Then the generator, which tries to trick the discriminator and should have an opposing loss function
#
#
# #### Saving Samples
#
# You've been given some code to print out some loss statistics and save some generated "fake" samples.

# %% [markdown]
# #### Exercise: Complete the training function
#
# Keep in mind that, if you've moved your models to GPU, you'll also have to move any model inputs to GPU.

# %%
def train(D, G, n_epochs, print_every=50):
    '''Trains adversarial networks for some number of epochs
       param, D: the discriminator network
       param, G: the generator network
       param, n_epochs: number of epochs to train for
       param, print_every: when to print and record the models' losses
       return: D and G losses'''
    
    # move models to GPU
    if train_on_gpu:
        D.cuda()
        G.cuda()

    # keep track of loss and generated, "fake" samples
    samples = []
    losses = []

    # Get some fixed data for sampling. These are images that are held
    # constant throughout training, and allow us to inspect the model's performance
    sample_size=16
    fixed_z = np.random.uniform(-1, 1, size=(sample_size, z_size))
    fixed_z = torch.from_numpy(fixed_z).float()
    # move z to GPU if available
    if train_on_gpu:
        fixed_z = fixed_z.cuda()

    # epoch training loop
    for epoch in range(n_epochs):

        # batch training loop
        for batch_i, (real_images, _) in enumerate(celeba_train_loader):

            batch_size = real_images.size(0)
            real_images = scale(real_images)

            # ===============================================
            #         YOUR CODE HERE: TRAIN THE NETWORKS
            # ===============================================
            
            # 1. Train the discriminator on real and fake images
            
            d_optimizer.zero_grad()   # clear out gradients
            g_optimizer.zero_grad()   # clear out gradients
            
            z = np.random.uniform(-1, 1, size=(batch_size, z_size))
            z = torch.from_numpy(z).float()
                 
            if train_on_gpu:
                real_images = real_images.cuda()
                z = z.cuda()
            
            d_loss = real_loss(D(real_images)) + fake_loss(D(G(z)))
            #d_loss = CEL_real_loss(D(real_images)) + CEL_fake_loss(D(G(z)))   # Using CrossEntropyLoss w/sigmoid instead of LS GAN
            d_loss.backward()
            d_optimizer.step()

            # 2. Train the generator with an adversarial loss
            
            g_loss = real_loss(D(G(z)))
            #g_loss = CEL_real_loss(D(G(z)))   # Using CrossEntropyLoss with sigmoid instead of LS GAN loss
            g_loss.backward()
            g_optimizer.step()
            
            # ===============================================
            #              END OF YOUR CODE
            # ===============================================

            # Print some loss stats
            if batch_i % print_every == 0:
                # append discriminator loss and generator loss
                losses.append((d_loss.item(), g_loss.item()))
                # print discriminator and generator loss
                print('Epoch [{:5d}/{:5d}] | Batch [{:5d}/{:5d}] | d_loss: {:6.4f} | g_loss: {:6.4f}'.format(
                        epoch+1, n_epochs, batch_i+1, len(celeba_train_loader), d_loss.item(), g_loss.item()))


        ## AFTER EACH EPOCH##    
        # this code assumes your generator is named G, feel free to change the name
        # generate and save sample, fake images
        G.eval() # for generating samples
        samples_z = G(fixed_z)
        samples.append(samples_z)
        G.train() # back to training mode

    # Save training generator samples
    with open('train_samples.pkl', 'wb') as f:
        pkl.dump(samples, f)
    
    
    checkpoint_every=20
    # Save the model parameters
    if epoch % checkpoint_every == 0:
            torch.save(D.state_dict(), os.path.join('checkpoints_FaceGeneration', 'D.pkl') )
            torch.save(G.state_dict(), os.path.join('checkpoints_FaceGeneration', 'G.pkl') )
            
    # finally return losses
    return losses

# %% [markdown]
# Set your number of training epochs and train your GAN!

# %%
# set number of epochs 
n_epochs = 20


"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# call training function
losses = train(D, G, n_epochs=n_epochs)
# Out:
# Epoch [    1/   20] | Batch [    1/  703] | d_loss: 1.2399 | g_loss: 0.5810
# Epoch [    1/   20] | Batch [   51/  703] | d_loss: 0.0517 | g_loss: 1.1184
# Epoch [    1/   20] | Batch [  101/  703] | d_loss: 0.1831 | g_loss: 1.2290
# Epoch [    1/   20] | Batch [  151/  703] | d_loss: 0.0801 | g_loss: 1.3907
# Epoch [    1/   20] | Batch [  201/  703] | d_loss: 0.5165 | g_loss: 1.8428
# Epoch [    1/   20] | Batch [  251/  703] | d_loss: 0.0696 | g_loss: 1.0091
# Epoch [    1/   20] | Batch [  301/  703] | d_loss: 0.0866 | g_loss: 0.8403
# Epoch [    1/   20] | Batch [  351/  703] | d_loss: 0.7554 | g_loss: 0.4599
# Epoch [    1/   20] | Batch [  401/  703] | d_loss: 0.0946 | g_loss: 0.7270
# Epoch [    1/   20] | Batch [  451/  703] | d_loss: 0.1234 | g_loss: 0.5636
# Epoch [    1/   20] | Batch [  501/  703] | d_loss: 0.4523 | g_loss: 0.6703
# Epoch [    1/   20] | Batch [  551/  703] | d_loss: 0.1258 | g_loss: 1.1529
# Epoch [    1/   20] | Batch [  601/  703] | d_loss: 0.2016 | g_loss: 0.5990
# Epoch [    1/   20] | Batch [  651/  703] | d_loss: 0.1641 | g_loss: 1.0868
# Epoch [    1/   20] | Batch [  701/  703] | d_loss: 0.8928 | g_loss: 2.1336
# Epoch [    2/   20] | Batch [    1/  703] | d_loss: 0.2071 | g_loss: 1.1028
# Epoch [    2/   20] | Batch [   51/  703] | d_loss: 0.1419 | g_loss: 1.0013
# Epoch [    2/   20] | Batch [  101/  703] | d_loss: 0.4641 | g_loss: 0.7426
# Epoch [    2/   20] | Batch [  151/  703] | d_loss: 0.1890 | g_loss: 0.9757
# Epoch [    2/   20] | Batch [  201/  703] | d_loss: 0.2657 | g_loss: 0.9740
# Epoch [    2/   20] | Batch [  251/  703] | d_loss: 0.2247 | g_loss: 0.6335
# Epoch [    2/   20] | Batch [  301/  703] | d_loss: 0.1481 | g_loss: 1.3210
# Epoch [    2/   20] | Batch [  351/  703] | d_loss: 0.2473 | g_loss: 0.7854
# Epoch [    2/   20] | Batch [  401/  703] | d_loss: 0.2286 | g_loss: 0.7449
# Epoch [    2/   20] | Batch [  451/  703] | d_loss: 0.2005 | g_loss: 0.7465
# Epoch [    2/   20] | Batch [  501/  703] | d_loss: 0.3137 | g_loss: 1.5064
# Epoch [    2/   20] | Batch [  551/  703] | d_loss: 0.2688 | g_loss: 0.9087
# Epoch [    2/   20] | Batch [  601/  703] | d_loss: 0.2648 | g_loss: 0.7288
# Epoch [    2/   20] | Batch [  651/  703] | d_loss: 0.2939 | g_loss: 1.1195
# Epoch [    2/   20] | Batch [  701/  703] | d_loss: 0.2834 | g_loss: 0.7674
# Epoch [    3/   20] | Batch [    1/  703] | d_loss: 0.3425 | g_loss: 1.1184
# Epoch [    3/   20] | Batch [   51/  703] | d_loss: 0.3251 | g_loss: 0.4241
# Epoch [    3/   20] | Batch [  101/  703] | d_loss: 0.2309 | g_loss: 0.7292
# Epoch [    3/   20] | Batch [  151/  703] | d_loss: 0.2106 | g_loss: 0.7577
# Epoch [    3/   20] | Batch [  201/  703] | d_loss: 0.3925 | g_loss: 1.3845
# Epoch [    3/   20] | Batch [  251/  703] | d_loss: 0.3089 | g_loss: 0.9346
# Epoch [    3/   20] | Batch [  301/  703] | d_loss: 0.3030 | g_loss: 1.1058
# Epoch [    3/   20] | Batch [  351/  703] | d_loss: 0.2717 | g_loss: 0.9899
# Epoch [    3/   20] | Batch [  401/  703] | d_loss: 0.1672 | g_loss: 1.0796
# Epoch [    3/   20] | Batch [  451/  703] | d_loss: 0.2656 | g_loss: 0.4581
# Epoch [    3/   20] | Batch [  501/  703] | d_loss: 0.2282 | g_loss: 0.8362
# Epoch [    3/   20] | Batch [  551/  703] | d_loss: 0.5599 | g_loss: 1.6175
# Epoch [    3/   20] | Batch [  601/  703] | d_loss: 0.2317 | g_loss: 0.4810
# Epoch [    3/   20] | Batch [  651/  703] | d_loss: 0.2244 | g_loss: 0.6609
# Epoch [    3/   20] | Batch [  701/  703] | d_loss: 0.2635 | g_loss: 0.9429
# Epoch [    4/   20] | Batch [    1/  703] | d_loss: 0.2478 | g_loss: 0.9479
# Epoch [    4/   20] | Batch [   51/  703] | d_loss: 0.2278 | g_loss: 0.6277
# Epoch [    4/   20] | Batch [  101/  703] | d_loss: 0.2360 | g_loss: 0.5760
# Epoch [    4/   20] | Batch [  151/  703] | d_loss: 0.2381 | g_loss: 0.4321
# Epoch [    4/   20] | Batch [  201/  703] | d_loss: 0.2695 | g_loss: 0.4473
# Epoch [    4/   20] | Batch [  251/  703] | d_loss: 0.3048 | g_loss: 0.4568
# Epoch [    4/   20] | Batch [  301/  703] | d_loss: 0.2763 | g_loss: 0.9351
# Epoch [    4/   20] | Batch [  351/  703] | d_loss: 0.1822 | g_loss: 0.7806
# Epoch [    4/   20] | Batch [  401/  703] | d_loss: 0.2451 | g_loss: 1.1158
# Epoch [    4/   20] | Batch [  451/  703] | d_loss: 0.1828 | g_loss: 0.7908
# Epoch [    4/   20] | Batch [  501/  703] | d_loss: 0.2571 | g_loss: 1.0721
# Epoch [    4/   20] | Batch [  551/  703] | d_loss: 0.2590 | g_loss: 0.5724
# Epoch [    4/   20] | Batch [  601/  703] | d_loss: 0.2692 | g_loss: 0.5986
# Epoch [    4/   20] | Batch [  651/  703] | d_loss: 0.2654 | g_loss: 0.4278
# Epoch [    4/   20] | Batch [  701/  703] | d_loss: 0.3085 | g_loss: 0.8849
# Epoch [    5/   20] | Batch [    1/  703] | d_loss: 0.2013 | g_loss: 0.6625
# Epoch [    5/   20] | Batch [   51/  703] | d_loss: 0.2433 | g_loss: 0.7814
# Epoch [    5/   20] | Batch [  101/  703] | d_loss: 0.1985 | g_loss: 0.6799
# Epoch [    5/   20] | Batch [  151/  703] | d_loss: 0.1403 | g_loss: 0.9132
# Epoch [    5/   20] | Batch [  201/  703] | d_loss: 0.2535 | g_loss: 0.5125
# Epoch [    5/   20] | Batch [  251/  703] | d_loss: 0.2344 | g_loss: 0.3995
# Epoch [    5/   20] | Batch [  301/  703] | d_loss: 1.6355 | g_loss: 2.4009
# Epoch [    5/   20] | Batch [  351/  703] | d_loss: 0.2265 | g_loss: 0.6633
# Epoch [    5/   20] | Batch [  401/  703] | d_loss: 0.1648 | g_loss: 0.8905
# Epoch [    5/   20] | Batch [  451/  703] | d_loss: 0.2091 | g_loss: 0.8643
# Epoch [    5/   20] | Batch [  501/  703] | d_loss: 0.1891 | g_loss: 0.7137
# Epoch [    5/   20] | Batch [  551/  703] | d_loss: 0.3139 | g_loss: 0.9610
# Epoch [    5/   20] | Batch [  601/  703] | d_loss: 0.1787 | g_loss: 0.7614
# Epoch [    5/   20] | Batch [  651/  703] | d_loss: 0.2897 | g_loss: 0.5471
# Epoch [    5/   20] | Batch [  701/  703] | d_loss: 0.1780 | g_loss: 0.8245
# Epoch [    6/   20] | Batch [    1/  703] | d_loss: 0.4980 | g_loss: 0.1085
# Epoch [    6/   20] | Batch [   51/  703] | d_loss: 0.1557 | g_loss: 0.7424
# Epoch [    6/   20] | Batch [  101/  703] | d_loss: 0.2143 | g_loss: 0.9017
# Epoch [    6/   20] | Batch [  151/  703] | d_loss: 0.1879 | g_loss: 0.5994
# Epoch [    6/   20] | Batch [  201/  703] | d_loss: 0.2339 | g_loss: 0.8099
# Epoch [    6/   20] | Batch [  251/  703] | d_loss: 0.2390 | g_loss: 0.6146
# Epoch [    6/   20] | Batch [  301/  703] | d_loss: 0.1999 | g_loss: 1.1203
# Epoch [    6/   20] | Batch [  351/  703] | d_loss: 0.2811 | g_loss: 0.7430
# Epoch [    6/   20] | Batch [  401/  703] | d_loss: 0.2948 | g_loss: 1.3215
# Epoch [    6/   20] | Batch [  451/  703] | d_loss: 0.2273 | g_loss: 0.6918
# Epoch [    6/   20] | Batch [  501/  703] | d_loss: 0.1939 | g_loss: 0.6723
# Epoch [    6/   20] | Batch [  551/  703] | d_loss: 0.2623 | g_loss: 0.7864
# Epoch [    6/   20] | Batch [  601/  703] | d_loss: 0.2507 | g_loss: 0.8527
# Epoch [    6/   20] | Batch [  651/  703] | d_loss: 0.1784 | g_loss: 0.9049
# Epoch [    6/   20] | Batch [  701/  703] | d_loss: 0.2335 | g_loss: 0.4910
# Epoch [    7/   20] | Batch [    1/  703] | d_loss: 0.2084 | g_loss: 0.6942
# Epoch [    7/   20] | Batch [   51/  703] | d_loss: 0.2280 | g_loss: 1.0852
# Epoch [    7/   20] | Batch [  101/  703] | d_loss: 0.1557 | g_loss: 1.2480
# Epoch [    7/   20] | Batch [  151/  703] | d_loss: 0.4268 | g_loss: 0.2464
# Epoch [    7/   20] | Batch [  201/  703] | d_loss: 0.1902 | g_loss: 0.8310
# Epoch [    7/   20] | Batch [  251/  703] | d_loss: 0.2340 | g_loss: 0.3862
# Epoch [    7/   20] | Batch [  301/  703] | d_loss: 0.2084 | g_loss: 0.7114
# Epoch [    7/   20] | Batch [  351/  703] | d_loss: 0.2640 | g_loss: 0.8923
# Epoch [    7/   20] | Batch [  401/  703] | d_loss: 0.2090 | g_loss: 0.6356
# Epoch [    7/   20] | Batch [  451/  703] | d_loss: 0.1599 | g_loss: 0.8922
# Epoch [    7/   20] | Batch [  501/  703] | d_loss: 0.1875 | g_loss: 0.6909
# Epoch [    7/   20] | Batch [  551/  703] | d_loss: 0.2024 | g_loss: 0.5625
# Epoch [    7/   20] | Batch [  601/  703] | d_loss: 0.2785 | g_loss: 0.3615
# Epoch [    7/   20] | Batch [  651/  703] | d_loss: 0.1945 | g_loss: 0.9818
# Epoch [    7/   20] | Batch [  701/  703] | d_loss: 0.2219 | g_loss: 0.8318
# Epoch [    8/   20] | Batch [    1/  703] | d_loss: 0.1762 | g_loss: 0.7670
# Epoch [    8/   20] | Batch [   51/  703] | d_loss: 0.1806 | g_loss: 0.9957
# Epoch [    8/   20] | Batch [  101/  703] | d_loss: 0.5869 | g_loss: 0.1710
# Epoch [    8/   20] | Batch [  151/  703] | d_loss: 0.1682 | g_loss: 1.0153
# Epoch [    8/   20] | Batch [  201/  703] | d_loss: 0.2474 | g_loss: 0.8964
# Epoch [    8/   20] | Batch [  251/  703] | d_loss: 0.1720 | g_loss: 0.7676
# Epoch [    8/   20] | Batch [  301/  703] | d_loss: 0.1613 | g_loss: 0.7694
# Epoch [    8/   20] | Batch [  351/  703] | d_loss: 0.2120 | g_loss: 0.5936
# Epoch [    8/   20] | Batch [  401/  703] | d_loss: 0.1940 | g_loss: 0.8022
# Epoch [    8/   20] | Batch [  451/  703] | d_loss: 0.1681 | g_loss: 0.6930
# Epoch [    8/   20] | Batch [  501/  703] | d_loss: 0.2318 | g_loss: 0.6065
# Epoch [    8/   20] | Batch [  551/  703] | d_loss: 0.4040 | g_loss: 1.7318
# Epoch [    8/   20] | Batch [  601/  703] | d_loss: 0.2398 | g_loss: 1.1359
# Epoch [    8/   20] | Batch [  651/  703] | d_loss: 0.2785 | g_loss: 1.5168
# Epoch [    8/   20] | Batch [  701/  703] | d_loss: 0.1467 | g_loss: 0.6512
# Epoch [    9/   20] | Batch [    1/  703] | d_loss: 0.2319 | g_loss: 0.4851
# Epoch [    9/   20] | Batch [   51/  703] | d_loss: 0.1933 | g_loss: 0.7250
# Epoch [    9/   20] | Batch [  101/  703] | d_loss: 0.1533 | g_loss: 0.8702
# Epoch [    9/   20] | Batch [  151/  703] | d_loss: 0.2041 | g_loss: 0.9650
# Epoch [    9/   20] | Batch [  201/  703] | d_loss: 0.1271 | g_loss: 0.9052
# Epoch [    9/   20] | Batch [  251/  703] | d_loss: 0.1940 | g_loss: 0.5954
# Epoch [    9/   20] | Batch [  301/  703] | d_loss: 0.2245 | g_loss: 0.6514
# Epoch [    9/   20] | Batch [  351/  703] | d_loss: 0.3083 | g_loss: 0.5693
# Epoch [    9/   20] | Batch [  401/  703] | d_loss: 0.2401 | g_loss: 0.9748
# Epoch [    9/   20] | Batch [  451/  703] | d_loss: 0.1923 | g_loss: 0.8536
# Epoch [    9/   20] | Batch [  501/  703] | d_loss: 0.1782 | g_loss: 0.5796
# Epoch [    9/   20] | Batch [  551/  703] | d_loss: 0.2149 | g_loss: 0.6033
# Epoch [    9/   20] | Batch [  601/  703] | d_loss: 0.1672 | g_loss: 1.2814
# Epoch [    9/   20] | Batch [  651/  703] | d_loss: 0.2826 | g_loss: 1.0112
# Epoch [    9/   20] | Batch [  701/  703] | d_loss: 0.1954 | g_loss: 0.6768
# Epoch [   10/   20] | Batch [    1/  703] | d_loss: 0.2065 | g_loss: 1.1500
# Epoch [   10/   20] | Batch [   51/  703] | d_loss: 0.2355 | g_loss: 0.6017
# Epoch [   10/   20] | Batch [  101/  703] | d_loss: 0.2330 | g_loss: 1.3710
# Epoch [   10/   20] | Batch [  151/  703] | d_loss: 0.1651 | g_loss: 0.7185
# Epoch [   10/   20] | Batch [  201/  703] | d_loss: 0.1610 | g_loss: 0.9050
# Epoch [   10/   20] | Batch [  251/  703] | d_loss: 0.2079 | g_loss: 0.8234
# Epoch [   10/   20] | Batch [  301/  703] | d_loss: 0.1800 | g_loss: 1.0554
# Epoch [   10/   20] | Batch [  351/  703] | d_loss: 0.1857 | g_loss: 0.9030
# Epoch [   10/   20] | Batch [  401/  703] | d_loss: 0.2019 | g_loss: 1.1791
# Epoch [   10/   20] | Batch [  451/  703] | d_loss: 0.2353 | g_loss: 0.9084
# Epoch [   10/   20] | Batch [  501/  703] | d_loss: 0.1946 | g_loss: 0.7379
# Epoch [   10/   20] | Batch [  551/  703] | d_loss: 0.1584 | g_loss: 0.7168
# Epoch [   10/   20] | Batch [  601/  703] | d_loss: 0.2300 | g_loss: 0.9782
# Epoch [   10/   20] | Batch [  651/  703] | d_loss: 0.1428 | g_loss: 0.9949
# Epoch [   10/   20] | Batch [  701/  703] | d_loss: 0.1591 | g_loss: 1.1603
# Epoch [   11/   20] | Batch [    1/  703] | d_loss: 0.2400 | g_loss: 0.5677
# Epoch [   11/   20] | Batch [   51/  703] | d_loss: 0.2127 | g_loss: 0.8575
# Epoch [   11/   20] | Batch [  101/  703] | d_loss: 0.1481 | g_loss: 1.0544
# Epoch [   11/   20] | Batch [  151/  703] | d_loss: 0.1383 | g_loss: 0.8818
# Epoch [   11/   20] | Batch [  201/  703] | d_loss: 0.1824 | g_loss: 0.6884
# Epoch [   11/   20] | Batch [  251/  703] | d_loss: 0.2380 | g_loss: 0.5627
# Epoch [   11/   20] | Batch [  301/  703] | d_loss: 0.2751 | g_loss: 0.5406
# Epoch [   11/   20] | Batch [  351/  703] | d_loss: 0.2351 | g_loss: 0.8669
# Epoch [   11/   20] | Batch [  401/  703] | d_loss: 0.2253 | g_loss: 0.9752
# Epoch [   11/   20] | Batch [  451/  703] | d_loss: 0.2213 | g_loss: 1.1721
# Epoch [   11/   20] | Batch [  501/  703] | d_loss: 0.2253 | g_loss: 0.7144
# Epoch [   11/   20] | Batch [  551/  703] | d_loss: 0.1512 | g_loss: 0.9994
# Epoch [   11/   20] | Batch [  601/  703] | d_loss: 0.2573 | g_loss: 0.4614
# Epoch [   11/   20] | Batch [  651/  703] | d_loss: 0.2088 | g_loss: 0.4888
# Epoch [   11/   20] | Batch [  701/  703] | d_loss: 0.4555 | g_loss: 0.3915
# Epoch [   12/   20] | Batch [    1/  703] | d_loss: 0.3955 | g_loss: 0.3782
# Epoch [   12/   20] | Batch [   51/  703] | d_loss: 0.2374 | g_loss: 0.6400
# Epoch [   12/   20] | Batch [  101/  703] | d_loss: 0.2129 | g_loss: 0.5699
# Epoch [   12/   20] | Batch [  151/  703] | d_loss: 0.1805 | g_loss: 0.9842
# Epoch [   12/   20] | Batch [  201/  703] | d_loss: 0.1851 | g_loss: 0.7187
# Epoch [   12/   20] | Batch [  251/  703] | d_loss: 0.4538 | g_loss: 1.4711
# Epoch [   12/   20] | Batch [  301/  703] | d_loss: 0.1130 | g_loss: 0.7157
# Epoch [   12/   20] | Batch [  351/  703] | d_loss: 0.1490 | g_loss: 0.8565
# Epoch [   12/   20] | Batch [  401/  703] | d_loss: 0.2325 | g_loss: 0.9522
# Epoch [   12/   20] | Batch [  451/  703] | d_loss: 0.3498 | g_loss: 2.0641
# Epoch [   12/   20] | Batch [  501/  703] | d_loss: 0.2587 | g_loss: 0.4842
# Epoch [   12/   20] | Batch [  551/  703] | d_loss: 0.1973 | g_loss: 0.7862
# Epoch [   12/   20] | Batch [  601/  703] | d_loss: 0.2719 | g_loss: 0.4289
# Epoch [   12/   20] | Batch [  651/  703] | d_loss: 0.2020 | g_loss: 1.1113
# Epoch [   12/   20] | Batch [  701/  703] | d_loss: 0.2100 | g_loss: 0.5547
# Epoch [   13/   20] | Batch [    1/  703] | d_loss: 0.2484 | g_loss: 0.4930
# Epoch [   13/   20] | Batch [   51/  703] | d_loss: 0.1315 | g_loss: 0.7592
# Epoch [   13/   20] | Batch [  101/  703] | d_loss: 0.1284 | g_loss: 0.7951
# Epoch [   13/   20] | Batch [  151/  703] | d_loss: 0.1539 | g_loss: 0.6974
# Epoch [   13/   20] | Batch [  201/  703] | d_loss: 0.2074 | g_loss: 0.4960
# Epoch [   13/   20] | Batch [  251/  703] | d_loss: 0.1713 | g_loss: 0.9119
# Epoch [   13/   20] | Batch [  301/  703] | d_loss: 0.2347 | g_loss: 0.5047
# Epoch [   13/   20] | Batch [  351/  703] | d_loss: 0.1296 | g_loss: 0.8673
# Epoch [   13/   20] | Batch [  401/  703] | d_loss: 0.1397 | g_loss: 0.8987
# Epoch [   13/   20] | Batch [  451/  703] | d_loss: 0.1147 | g_loss: 0.7143
# Epoch [   13/   20] | Batch [  501/  703] | d_loss: 0.1099 | g_loss: 0.8719
# Epoch [   13/   20] | Batch [  551/  703] | d_loss: 0.2033 | g_loss: 0.7436
# Epoch [   13/   20] | Batch [  601/  703] | d_loss: 0.1669 | g_loss: 0.6452
# Epoch [   13/   20] | Batch [  651/  703] | d_loss: 0.1601 | g_loss: 1.0150
# Epoch [   13/   20] | Batch [  701/  703] | d_loss: 0.2537 | g_loss: 0.5681
# Epoch [   14/   20] | Batch [    1/  703] | d_loss: 0.1775 | g_loss: 0.5234
# Epoch [   14/   20] | Batch [   51/  703] | d_loss: 0.2329 | g_loss: 0.5377
# Epoch [   14/   20] | Batch [  101/  703] | d_loss: 0.1712 | g_loss: 0.7016
# Epoch [   14/   20] | Batch [  151/  703] | d_loss: 0.0999 | g_loss: 0.7625
# Epoch [   14/   20] | Batch [  201/  703] | d_loss: 0.1719 | g_loss: 0.6179
# Epoch [   14/   20] | Batch [  251/  703] | d_loss: 0.1621 | g_loss: 0.5291
# Epoch [   14/   20] | Batch [  301/  703] | d_loss: 0.1237 | g_loss: 0.7178
# Epoch [   14/   20] | Batch [  351/  703] | d_loss: 0.1132 | g_loss: 0.8143
# Epoch [   14/   20] | Batch [  401/  703] | d_loss: 0.1574 | g_loss: 0.6832
# Epoch [   14/   20] | Batch [  451/  703] | d_loss: 0.1184 | g_loss: 0.7864
# Epoch [   14/   20] | Batch [  501/  703] | d_loss: 0.1284 | g_loss: 0.7665
# Epoch [   14/   20] | Batch [  551/  703] | d_loss: 0.1163 | g_loss: 0.8751
# Epoch [   14/   20] | Batch [  601/  703] | d_loss: 0.1535 | g_loss: 0.6041
# Epoch [   14/   20] | Batch [  651/  703] | d_loss: 0.1083 | g_loss: 0.8859
# Epoch [   14/   20] | Batch [  701/  703] | d_loss: 0.1528 | g_loss: 0.8567
# Epoch [   15/   20] | Batch [    1/  703] | d_loss: 0.1366 | g_loss: 0.6718
# Epoch [   15/   20] | Batch [   51/  703] | d_loss: 0.1167 | g_loss: 1.0499
# Epoch [   15/   20] | Batch [  101/  703] | d_loss: 0.1879 | g_loss: 1.3005
# Epoch [   15/   20] | Batch [  151/  703] | d_loss: 0.1271 | g_loss: 0.8305
# Epoch [   15/   20] | Batch [  201/  703] | d_loss: 0.1910 | g_loss: 0.6926
# Epoch [   15/   20] | Batch [  251/  703] | d_loss: 0.1546 | g_loss: 0.7564
# Epoch [   15/   20] | Batch [  301/  703] | d_loss: 0.1816 | g_loss: 1.0705
# Epoch [   15/   20] | Batch [  351/  703] | d_loss: 0.1105 | g_loss: 1.2115
# Epoch [   15/   20] | Batch [  401/  703] | d_loss: 0.1217 | g_loss: 1.0809
# Epoch [   15/   20] | Batch [  451/  703] | d_loss: 0.3071 | g_loss: 1.2276
# Epoch [   15/   20] | Batch [  501/  703] | d_loss: 0.1466 | g_loss: 0.8405
# Epoch [   15/   20] | Batch [  551/  703] | d_loss: 0.0615 | g_loss: 1.0630
# Epoch [   15/   20] | Batch [  601/  703] | d_loss: 0.1563 | g_loss: 0.7293
# Epoch [   15/   20] | Batch [  651/  703] | d_loss: 0.1335 | g_loss: 0.5985
# Epoch [   15/   20] | Batch [  701/  703] | d_loss: 0.1594 | g_loss: 0.6546
# Epoch [   16/   20] | Batch [    1/  703] | d_loss: 0.2197 | g_loss: 1.1046
# Epoch [   16/   20] | Batch [   51/  703] | d_loss: 0.1223 | g_loss: 0.7212
# Epoch [   16/   20] | Batch [  101/  703] | d_loss: 0.2103 | g_loss: 0.5220
# Epoch [   16/   20] | Batch [  151/  703] | d_loss: 0.1756 | g_loss: 1.0801
# Epoch [   16/   20] | Batch [  201/  703] | d_loss: 0.1675 | g_loss: 0.7001
# Epoch [   16/   20] | Batch [  251/  703] | d_loss: 0.2415 | g_loss: 0.5180
# Epoch [   16/   20] | Batch [  301/  703] | d_loss: 0.1502 | g_loss: 0.6850
# Epoch [   16/   20] | Batch [  351/  703] | d_loss: 0.3510 | g_loss: 0.2924
# Epoch [   16/   20] | Batch [  401/  703] | d_loss: 0.1481 | g_loss: 0.5806
# Epoch [   16/   20] | Batch [  451/  703] | d_loss: 0.1609 | g_loss: 0.6613
# Epoch [   16/   20] | Batch [  501/  703] | d_loss: 0.0934 | g_loss: 0.8338
# Epoch [   16/   20] | Batch [  551/  703] | d_loss: 0.1328 | g_loss: 0.9452
# Epoch [   16/   20] | Batch [  601/  703] | d_loss: 0.1392 | g_loss: 1.1435
# Epoch [   16/   20] | Batch [  651/  703] | d_loss: 0.1485 | g_loss: 0.8646
# Epoch [   16/   20] | Batch [  701/  703] | d_loss: 0.1965 | g_loss: 0.7544
# Epoch [   17/   20] | Batch [    1/  703] | d_loss: 0.1437 | g_loss: 1.3900
# Epoch [   17/   20] | Batch [   51/  703] | d_loss: 0.0672 | g_loss: 0.9891
# Epoch [   17/   20] | Batch [  101/  703] | d_loss: 0.1594 | g_loss: 0.6133
# Epoch [   17/   20] | Batch [  151/  703] | d_loss: 0.1484 | g_loss: 0.7461
# Epoch [   17/   20] | Batch [  201/  703] | d_loss: 0.2894 | g_loss: 1.5908
# Epoch [   17/   20] | Batch [  251/  703] | d_loss: 0.1398 | g_loss: 0.6660
# Epoch [   17/   20] | Batch [  301/  703] | d_loss: 0.1324 | g_loss: 0.8774
# Epoch [   17/   20] | Batch [  351/  703] | d_loss: 0.1952 | g_loss: 1.5960
# Epoch [   17/   20] | Batch [  401/  703] | d_loss: 0.0768 | g_loss: 1.0967
# Epoch [   17/   20] | Batch [  451/  703] | d_loss: 0.0962 | g_loss: 0.8067
# Epoch [   17/   20] | Batch [  501/  703] | d_loss: 0.1520 | g_loss: 1.0360
# Epoch [   17/   20] | Batch [  551/  703] | d_loss: 0.0975 | g_loss: 1.0736
# Epoch [   17/   20] | Batch [  601/  703] | d_loss: 0.0985 | g_loss: 0.8697
# Epoch [   17/   20] | Batch [  651/  703] | d_loss: 0.1132 | g_loss: 1.1904
# Epoch [   17/   20] | Batch [  701/  703] | d_loss: 0.2129 | g_loss: 1.2379
# Epoch [   18/   20] | Batch [    1/  703] | d_loss: 0.1610 | g_loss: 1.5803
# Epoch [   18/   20] | Batch [   51/  703] | d_loss: 0.1341 | g_loss: 0.8461
# Epoch [   18/   20] | Batch [  101/  703] | d_loss: 0.1398 | g_loss: 0.7030
# Epoch [   18/   20] | Batch [  151/  703] | d_loss: 0.0972 | g_loss: 0.7541
# Epoch [   18/   20] | Batch [  201/  703] | d_loss: 0.1586 | g_loss: 0.6574
# Epoch [   18/   20] | Batch [  251/  703] | d_loss: 0.1325 | g_loss: 1.1367
# Epoch [   18/   20] | Batch [  301/  703] | d_loss: 0.1307 | g_loss: 1.3678
# Epoch [   18/   20] | Batch [  351/  703] | d_loss: 0.0779 | g_loss: 0.9966
# Epoch [   18/   20] | Batch [  401/  703] | d_loss: 0.1341 | g_loss: 0.7871
# Epoch [   18/   20] | Batch [  451/  703] | d_loss: 0.2984 | g_loss: 0.5952
# Epoch [   18/   20] | Batch [  501/  703] | d_loss: 0.1150 | g_loss: 0.7616
# Epoch [   18/   20] | Batch [  551/  703] | d_loss: 0.0995 | g_loss: 1.0534
# Epoch [   18/   20] | Batch [  601/  703] | d_loss: 0.2091 | g_loss: 0.6978
# Epoch [   18/   20] | Batch [  651/  703] | d_loss: 0.1009 | g_loss: 0.8516
# Epoch [   18/   20] | Batch [  701/  703] | d_loss: 0.0881 | g_loss: 1.4361
# Epoch [   19/   20] | Batch [    1/  703] | d_loss: 0.1347 | g_loss: 1.1142
# Epoch [   19/   20] | Batch [   51/  703] | d_loss: 0.1376 | g_loss: 0.6926
# Epoch [   19/   20] | Batch [  101/  703] | d_loss: 0.1272 | g_loss: 0.7359
# Epoch [   19/   20] | Batch [  151/  703] | d_loss: 0.0729 | g_loss: 0.9084
# Epoch [   19/   20] | Batch [  201/  703] | d_loss: 0.0866 | g_loss: 0.9219
# Epoch [   19/   20] | Batch [  251/  703] | d_loss: 0.1288 | g_loss: 0.9742
# Epoch [   19/   20] | Batch [  301/  703] | d_loss: 0.1689 | g_loss: 1.0703
# Epoch [   19/   20] | Batch [  351/  703] | d_loss: 0.1230 | g_loss: 0.6743
# Epoch [   19/   20] | Batch [  401/  703] | d_loss: 0.1218 | g_loss: 0.7788
# Epoch [   19/   20] | Batch [  451/  703] | d_loss: 0.1124 | g_loss: 1.1382
# Epoch [   19/   20] | Batch [  501/  703] | d_loss: 0.1444 | g_loss: 1.4789
# Epoch [   19/   20] | Batch [  551/  703] | d_loss: 0.1599 | g_loss: 0.6077
# Epoch [   19/   20] | Batch [  601/  703] | d_loss: 0.0934 | g_loss: 1.2059
# Epoch [   19/   20] | Batch [  651/  703] | d_loss: 0.1166 | g_loss: 1.0031
# Epoch [   19/   20] | Batch [  701/  703] | d_loss: 0.1094 | g_loss: 1.0001
# Epoch [   20/   20] | Batch [    1/  703] | d_loss: 0.0826 | g_loss: 1.1894
# Epoch [   20/   20] | Batch [   51/  703] | d_loss: 0.1679 | g_loss: 0.6655
# Epoch [   20/   20] | Batch [  101/  703] | d_loss: 0.2138 | g_loss: 0.5157
# Epoch [   20/   20] | Batch [  151/  703] | d_loss: 0.0763 | g_loss: 0.9548
# Epoch [   20/   20] | Batch [  201/  703] | d_loss: 0.0834 | g_loss: 1.0002
# Epoch [   20/   20] | Batch [  251/  703] | d_loss: 0.2139 | g_loss: 0.4748
# Epoch [   20/   20] | Batch [  301/  703] | d_loss: 0.1546 | g_loss: 1.1803
# Epoch [   20/   20] | Batch [  351/  703] | d_loss: 0.1048 | g_loss: 0.9768
# Epoch [   20/   20] | Batch [  401/  703] | d_loss: 0.0718 | g_loss: 1.0000
# Epoch [   20/   20] | Batch [  451/  703] | d_loss: 0.0752 | g_loss: 0.8601
# Epoch [   20/   20] | Batch [  501/  703] | d_loss: 0.0842 | g_loss: 0.9524
# Epoch [   20/   20] | Batch [  551/  703] | d_loss: 0.2403 | g_loss: 1.4425
# Epoch [   20/   20] | Batch [  601/  703] | d_loss: 0.1385 | g_loss: 1.1367
# Epoch [   20/   20] | Batch [  651/  703] | d_loss: 0.1055 | g_loss: 1.2938
# Epoch [   20/   20] | Batch [  701/  703] | d_loss: 0.0672 | g_loss: 0.8589

# %% [markdown]
# ## Training loss
#
# Plot the training losses for the generator and discriminator, recorded after each epoch.

# %%
fig, ax = plt.subplots()
losses = np.array(losses)
plt.plot(losses.T[0], label='Discriminator', alpha=0.5)
plt.plot(losses.T[1], label='Generator', alpha=0.5)
plt.title("Training Losses")
plt.legend()

# %% [markdown]
# ## Generator samples from training
#
# View samples of images from the generator, and answer a question about the strengths and weaknesses of your trained models.

# %%
# helper function for viewing a list of passed in sample images
def view_samples(epoch, samples):
    fig, axes = plt.subplots(figsize=(16,4), nrows=2, ncols=8, sharey=True, sharex=True)
    for ax, img in zip(axes.flatten(), samples[epoch]):
        img = img.detach().cpu().numpy()
        img = np.transpose(img, (1, 2, 0))
        img = ((img + 1)*255 / (2)).astype(np.uint8)
        ax.xaxis.set_visible(False)
        ax.yaxis.set_visible(False)
        im = ax.imshow(img.reshape((32,32,3)))

# %%
# Load samples from generator, taken while training
with open('train_samples.pkl', 'rb') as f:
    samples = pkl.load(f)

# %%
_ = view_samples(-1, samples)

# %% [markdown]
# ### Question: What do you notice about your generated samples and how might you improve this model?
# When you answer this question, consider the following factors:
# * The dataset is biased; it is made of "celebrity" faces that are mostly white
# * Model size; larger models have the opportunity to learn more features in a data feature space
# * Optimization strategy; optimizers and number of epochs affect your final result

# %% [markdown]
# **Answer:** (Write your answer in this cell)
# All generated samples have light skin color. this is due to the fact the training set is biased towards mostly white celebrity and under representation of other skin colors.
# The training picture are small size of 32x32. This might hinder capabilities to learn feature details allowing for a richer representation of a face. The generated output are therefore coarse and lack details. The model is able to capture larger details like hair color, hair style...Larger pictures could allow to learn higher details and output higher quality representations.
#
# I ran the model for 100 epochs which took over 2 hours. But the model did not converge. I changed my Generator model structure from using kernel=2, stride=2, padding=0 to kernel=4, stride=2, padding=1 and i went back to smaller training. The model gave good results with 20 epochs and the generation deteriorated significatively with 40 epochs (only a few features overwhelming all generated faces). Looking at the loss evolution profile, we can see the high fluctuations of the generator loss typical of GANs. Early stopping techniques, fit for classification tasks and using validation set, do not appear suitable for GANs. As a consequence it is difficult to determine the proper training length. Although difficult to see, the loss seems to reduce overtime at a macro level. Therefore training longer should futher improve the model capability to generate realistic faces.
#
#
# Architecture & Hyperparameters
# I used the hyperparameters (lr, beta1 & 2) recommended in publication "Unsupervised learning with deep convolutional GANs" since the objective relates to similar image and face generation. I used a batch size of 128 similar to the paper but a lower value might work for training. I followed key recommendations and architecture guidelines for stable Deep Convolutional GANs from Unsupervised learning with deep convolutional GANs:
# • Replace any pooling layers with strided convolutions (discriminator) and fractional-strided convolutions (generator).
# • Use batchnorm in both the generator and the discriminator.
# • Remove fully connected hidden layers for deeper architectures.
# • Use ReLU activation in generator for all layers except for the output, which uses Tanh.
# • Use LeakyReLU activation in the discriminator for all layers (excepted the output layer)
#
# I have planned for two loss function options:
# - Least square GANS which is very intuitive. Like CycleGan exercise, i did not use a sigmoid (no activation function) for final output
# - CrossEntropyLoss with sigmoid included
#
# I used the LS GANs one used in CycleGAN because it is straight-forward and delivered results.

# %% [markdown]
# ### Submitting This Project
# When submitting this project, make sure to run all the cells before saving the notebook. Save the notebook file as "dlnd_face_generation.ipynb" and save it as a HTML file under "File" -> "Download as". Include the "problem_unittests.py" files in your submission.
